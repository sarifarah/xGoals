# %% [markdown]
# # 1. Data Loading

# %% [markdown]
# **Sari Farah**
#
# **BrainStation, Data Science**
#
# **Next Notebook: 2. EDA**

# %% [markdown]
# Football, how can it be assessed? How can it be better quanitified?
#
# In this project, I want to gain a better understanding of the factors that make a shot successful. In particular I want to understand how angle and distance affect the result of the shot.
#
# This project will be using data from an webscraper. It is data from 5 seasons of football spanning from the 2015/2016 season all the way to 2019/2020 season, that is shots from five whole seasons of football. This data will be taken from the top five european leagues which are the English Premier League, Spanish La Liga, Italian Serie A, the German Bundesliga, and the French Ligue 1.
#
# The data used for this project was acquired by scraping the understat.com website. Understat.com is a top football statistics website used by many to follow their favourit leagues and dig deeper into football statistics. The scraped data was uploaded ot PyPI, a python library repository and can be found at this link https://pypi.org/project/understatscraper/0.0.2/.
# The data consists every shot in every game in the seasons and leagues specified above. We will see what the columns and rows are below.
#
# The way the webscraper is set up doesnt allow us to scrape all the data we need at once, so we must scrape it using a season/league combination. This is done below. The instructions for scraping the data are also outlined in the link above.
# The goal of this notebook is to scrape and concatenate all the season/league combinations into one dataframe in order to use in our next notebook (EDA).
#
# Let's read in the data.
#
# Note: It takes a while to load in the data below.

# %% [markdown]
# First, we will need to import our packages.

# %%
#Libraries I need
import pandas as pd 
import numpy as np

#Data source API
from understatscraper import Understat

# %%
#All the match Id's from top 5 leagues, between seasons 2015/2016-2019/2020
data = pd.read_csv('/Users/sarifarah/Desktop/Capstone/Understat_match_ids.csv')
data
# Out:
#        Unnamed: 0  match_id  year competition
# 0               0        81  2015         EPL
# 1               1        82  2015         EPL
# 2               2        83  2015         EPL
# 3               3        84  2015         EPL
# 4               4        85  2015         EPL
# ...           ...       ...   ...         ...
# 12868        1371     17867  2021     Ligue 1
# 12869        1372     17868  2021     Ligue 1
# 12870        1373     17869  2021     Ligue 1
# 12871        1374     17870  2021     Ligue 1
# 12872        1375     17871  2021     Ligue 1
#
# [12873 rows x 4 columns]

# %%
#initializing the API 
understat = Understat()

# %%
#testing the API on a random match  
df = understat.single_match(16415) 
df
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   430890      8  MissedShots  0.6869999694824219    0.664000015258789
# 1   430896     27    SavedShot  0.9230000305175782   0.3509999847412109
# 2   430897     31    SavedShot  0.9119999694824219   0.5729999923706055
# 3   430898     39  MissedShots  0.9019999694824219                0.625
# 4   430899     47  BlockedShot   0.754000015258789    0.605999984741211
# 5   430900     50  BlockedShot  0.8719999694824219   0.5459999847412109
# ...

# %% [markdown]
# Scraping the data from season 2015/2016 from the premier league

# %%
#scrapping english premier league for season 2015/2016
EPL_2015 = understat.season('EPL', 2015)
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')

# %%
#printing data for english premier league for season 2015/2016
EPL_2015
# Out:
#         id minute       result                   X                    Y  \
# 0   200247     27  BlockedShot   0.794000015258789   0.4209999847412109
# 1   200248     27  BlockedShot                0.86   0.6270000076293946
# 2   200249     35  BlockedShot  0.8430000305175781  0.33299999237060546
# 3   200250     35  MissedShots  0.8480000305175781   0.5329999923706055
# 4   200251     40  BlockedShot  0.8119999694824219   0.7069999694824218
# ..     ...    ...          ...                 ...                  ...
# 2    52055     46  BlockedShot  0.8419999694824218    0.539000015258789
# 3    52056     47  BlockedShot  0.8569999694824219   0.3189999961853027
# 4    52057     47  MissedShots  0.8419999694824218   0.5479999923706055
# 5    52065     85  MissedShots   0.875999984741211   0.5420000076293945
# 6    52068     92  MissedShots                0.91   0.5690000152587891
#
#                      xG         player h_a player_id       situation season  \
# ...

# %% [markdown]
# Scraping the data from season 2015/2016 from La liga

# %%
#scrapping spanish la liga for season 2015/2016
La_liga_2015 = understat.season('La liga', 2015)

# %%
#printing data for spanish la liga for season 2015/2016
La_liga_2015
# Out:
#        id minute       result                   X                    Y  \
# 0   84020     10  BlockedShot                 0.9   0.7630000305175781
# 1   84021     10    SavedShot  0.7390000152587891  0.48700000762939455
# 2   84026     16  MissedShots  0.6680000305175782                 0.51
# 3   84028     19  MissedShots  0.8590000152587891   0.3060000038146973
# 4   84029     20  MissedShots  0.7809999847412109    0.664000015258789
# ..    ...    ...          ...                 ...                  ...
# 3   92977     66  BlockedShot  0.7219999694824218   0.5279999923706055
# 4   92979     67    SavedShot   0.960999984741211   0.3940000152587891
# 5   92980     67  MissedShots   0.955999984741211   0.3940000152587891
# 6   92982     76  BlockedShot  0.8180000305175781   0.4779999923706055
# 7   92984     86   ShotOnPost  0.8859999847412109  0.33799999237060546
#
#                       xG           player h_a player_id   situation season  \
# ...

# %% [markdown]
# Scraping the data from season 2015/2016 from ligue 1

# %%
#scrapping french ligue 1 for season 2015/2016
Ligue_1_2015 = understat.season('Ligue 1', 2015)
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')

# %%
#printing data for french ligue 1 for season 2015/2016
Ligue_1_2015
# Out:
#        id minute       result                   X                    Y  \
# 0   61405      8  BlockedShot                0.87   0.3940000152587891
# 1   61406      8  BlockedShot               0.705   0.5279999923706055
# 2   61409     41  BlockedShot  0.7580000305175781  0.36200000762939455
# 3   61410     43    SavedShot  0.7280000305175781                0.685
# 4   61411     52  BlockedShot  0.8109999847412109  0.45799999237060546
# ..    ...    ...          ...                 ...                  ...
# 9   68494     60  MissedShots               0.795   0.7230000305175781
# 10  68496     64  MissedShots  0.8830000305175781  0.34700000762939454
# 11  68497     74    SavedShot  0.9019999694824219   0.3129999923706055
# 12  68499     77         Goal  0.9319999694824219   0.4779999923706055
# 13  68500     79         Goal   0.874000015258789  0.19700000762939454
#
#                       xG              player h_a player_id       situation  \
# ...

# %% [markdown]
# Scraping the data from season 2015/2016 from Bundesliga

# %%
#scrapping german bundesliga for season 2015/2016
Bundesliga_2015 = understat.season('Bundesliga', 2015)
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')

# %%
#printing data for german bundesliga for season 2015/2016
Bundesliga_2015
# Out:
#        id minute       result                   X                    Y  \
# 0   76058      7  MissedShots   0.865999984741211                 0.49
# 1   76059      8  BlockedShot  0.8769999694824219  0.30100000381469727
# 2   76060     16  MissedShots                0.91                 0.54
# 3   76061     20  MissedShots  0.9119999694824219                 0.47
# 4   76062     26         Goal  0.9440000152587891  0.48700000762939455
# ..    ...    ...          ...                 ...                  ...
# 17  83962     70  BlockedShot  0.8219999694824218   0.5790000152587891
# 18  83963     74  MissedShots  0.9380000305175781   0.4209999847412109
# 19  83964     76   ShotOnPost  0.9730000305175781  0.40900001525878904
# 20  83965     76  MissedShots   0.855999984741211   0.3240000152587891
# 21  83969     82  BlockedShot  0.8119999694824219  0.44299999237060544
#
#                      xG               player h_a player_id   situation season  \
# ...

# %% [markdown]
# Scraping the data from season 2015/2016 from Seria A

# %%
#scrapping italian Serie A for season 2015/2016
Serie_A_2015 = understat.season('Serie A', 2015)

# %%
#printing data for italian Serie A for season 2015/2016
Serie_A_2015
# Out:
#         id minute       result                   X                    Y  \
# 0    93141      1  MissedShots               0.825   0.7030000305175781
# 1    93144     13  MissedShots               0.865   0.6359999847412109
# 2    93146     17  BlockedShot                 0.9   0.3990000152587891
# 3    93149     28    SavedShot   0.759000015258789    0.544000015258789
# 4    93153     40    SavedShot  0.8880000305175781   0.7130000305175781
# ..     ...    ...          ...                 ...                  ...
# 9   102788     56  MissedShots  0.7619999694824219                0.555
# 10  102790     73  BlockedShot               0.875  0.22899999618530273
# 11  102791     73  BlockedShot   0.884000015258789  0.22899999618530273
# 12  102792     74  BlockedShot   0.740999984741211    0.509000015258789
# 13  102793     83         Goal  0.9490000152587891  0.45799999237060546
#
#                       xG             player h_a player_id   situation season  \
# ...

# %% [markdown]
# Concatenating all the leagues for season 2015/2016.
# I continue to do this all the way along the rest of the notebook for all seasons and leagues.

# %%
#Concatenating All the 2015/2016 shots data into one dataframe and renaming it  
All_leagues_2015 = [EPL_2015, La_liga_2015, Ligue_1_2015, Bundesliga_2015, Serie_A_2015]
Shots_2015 = pd.concat(All_leagues_2015)

# %%
Shots_2015
# Out:
#         id minute       result                   X                    Y  \
# 0   200247     27  BlockedShot   0.794000015258789   0.4209999847412109
# 1   200248     27  BlockedShot                0.86   0.6270000076293946
# 2   200249     35  BlockedShot  0.8430000305175781  0.33299999237060546
# 3   200250     35  MissedShots  0.8480000305175781   0.5329999923706055
# 4   200251     40  BlockedShot  0.8119999694824219   0.7069999694824218
# ..     ...    ...          ...                 ...                  ...
# 9   102788     56  MissedShots  0.7619999694824219                0.555
# 10  102790     73  BlockedShot               0.875  0.22899999618530273
# 11  102791     73  BlockedShot   0.884000015258789  0.22899999618530273
# 12  102792     74  BlockedShot   0.740999984741211    0.509000015258789
# 13  102793     83         Goal  0.9490000152587891  0.45799999237060546
#
#                       xG             player h_a player_id       situation  \
# ...

# %%
EPL_2016 = understat.season('EPL', 2016)
EPL_2016
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   112236      5  MissedShots  0.9159999847412109                0.585
# 1   112242     29  MissedShots  0.7580000305175781  0.18799999237060547
# 2   112243     33  MissedShots  0.8390000152587891   0.3240000152587891
# 3   112247     41  MissedShots  0.7480000305175781   0.3240000152587891
# 4   112249     45    SavedShot  0.9230000305175782    0.605999984741211
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
La_liga_2016 = understat.season('La liga', 2016)
La_liga_2016
# Out:
#         id minute       result                    X                    Y  \
# 0   135101      2  MissedShots   0.9009999847412109   0.6480000305175782
# 1   135102     23  BlockedShot                 0.92  0.48700000762939455
# 2   135103     24  MissedShots   0.8330000305175781   0.5709999847412109
# 3   135105     35  MissedShots                0.725                 0.46
# 4   135106     37    SavedShot    0.975999984741211  0.43599998474121093
# ..     ...    ...          ...                  ...                  ...
# 13  143859     64  MissedShots  0.47400001525878904                 0.73
# 14  143864     79  MissedShots   0.7709999847412109   0.6669999694824219
# 15  143865     81         Goal   0.8690000152587891   0.5529999923706055
# 16  143868     91  MissedShots                0.875  0.48700000762939455
# 17  143869     93         Goal                  0.9  0.48200000762939454
#
#                       xG           player h_a player_id   situation season  \
# ...

# %%
Ligue_1_2016 = understat.season('Ligue 1', 2016) 
Ligue_1_2016
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   103038      4  MissedShots  0.6980000305175781   0.7569999694824219
# 1   103039      6  MissedShots                0.87   0.6140000152587891
# 2   103040      7  MissedShots               0.765    0.534000015258789
# 3   103041     13  MissedShots   0.740999984741211  0.48400001525878905
# 4   103042     19  MissedShots  0.9269999694824219                 0.46
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Bundesliga_2016 = understat.season('Bundesliga', 2016)
Bundesliga_2016
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   127429      6  BlockedShot  0.8730000305175781  0.47200000762939454
# 1   127430      8         Goal  0.7190000152587891  0.47200000762939454
# 2   127432     10    SavedShot                0.91  0.42700000762939455
# 3   127433     10  BlockedShot   0.879000015258789                 0.55
# 4   127434     12         Goal  0.9619999694824218   0.6759999847412109
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Serie_A_2016 = understat.season('Serie A', 2016)
Serie_A_2016
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   144481      9    SavedShot  0.6909999847412109  0.28899999618530275
# 1   144483     14  MissedShots  0.9619999694824218  0.48200000762939454
# 2   144485     20  MissedShots  0.8019999694824219  0.21299999237060546
# 3   144487     26  BlockedShot  0.7730000305175782                0.685
# 4   144488     26  MissedShots  0.9319999694824219   0.6329999923706054
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
All_leagues_2016 = [EPL_2016, La_liga_2016, Ligue_1_2016, Bundesliga_2016, Serie_A_2016]
Shots_2016 = pd.concat(All_leagues_2016)
Shots_2016
# Out:
#         id minute       result                   X                    Y  \
# 0   112236      5  MissedShots  0.9159999847412109                0.585
# 1   112242     29  MissedShots  0.7580000305175781  0.18799999237060547
# 2   112243     33  MissedShots  0.8390000152587891   0.3240000152587891
# 3   112247     41  MissedShots  0.7480000305175781   0.3240000152587891
# 4   112249     45    SavedShot  0.9230000305175782    0.605999984741211
# ..     ...    ...          ...                 ...                  ...
# 13  154374     79  MissedShots  0.8780000305175781   0.5120000076293946
# 14  154375     80  BlockedShot  0.8909999847412109                 0.63
# 15  154378     83  BlockedShot   0.764000015258789   0.2620000076293945
# 16  154379     84  BlockedShot  0.9269999694824219  0.45599998474121095
# 17  154382     91         Goal   0.985999984741211   0.4540000152587891
#
#                       xG             player h_a player_id       situation  \
# ...

# %%
EPL_2017 = understat.season('EPL', 2017)
EPL_2017
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   158133      1         Goal               0.885   0.5259999847412109
# 1   158136      7  MissedShots  0.8069999694824219                 0.72
# 2   158137     13    SavedShot  0.7859999847412109   0.6430000305175781
# 3   158138     21  BlockedShot  0.9059999847412109                0.605
# 4   158139     21  MissedShots  0.6759999847412109   0.5729999923706055
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
La_liga_2017 = understat.season('La liga', 2017)
La_liga_2017
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   169144      4  BlockedShot   0.774000015258789   0.6990000152587891
# 1   169145      6  MissedShots  0.9069999694824219   0.5059999847412109
# 2   169148     20  MissedShots   0.870999984741211   0.5929999923706055
# 3   169149     23    SavedShot               0.745    0.725999984741211
# 4   169150     23         Goal  0.9719999694824218  0.48200000762939454
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Ligue_1_2017 = understat.season('Ligue 1', 2017) 
Ligue_1_2017
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   161994      4  BlockedShot               0.915   0.7190000152587891
# 1   161996      9  MissedShots  0.9409999847412109  0.48700000762939455
# 2   161997     12  BlockedShot  0.8180000305175781    0.500999984741211
# 3   161998     13    SavedShot   0.919000015258789                0.295
# 4   161999     17  MissedShots  0.7609999847412109  0.31799999237060544
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Bundesliga_2017 = understat.season('Bundesliga', 2017)
Bundesliga_2017
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   165760      4    SavedShot  0.8219999694824218   0.3529999923706055
# 1   165761      8         Goal  0.9290000152587891  0.40599998474121096
# 2   165764     15  MissedShots  0.7090000152587891   0.6419999694824219
# 3   165765     17         Goal                0.97  0.45599998474121095
# 4   165767     22    SavedShot  0.9409999847412109                0.315
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Serie_A_2017 = understat.season('Serie A', 2017)
Serie_A_2017
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   172685      1  MissedShots  0.7680000305175781   0.7659999847412109
# 1   172686     11         Goal  0.8880000305175781    0.524000015258789
# 2   172687     24  MissedShots  0.7780000305175782  0.48200000762939454
# 3   172691     41  BlockedShot  0.7869999694824219  0.43400001525878906
# 4   172692     42    SavedShot   0.799000015258789  0.30100000381469727
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
All_leagues_2017 = [EPL_2017, La_liga_2017, Ligue_1_2017, Bundesliga_2017, Serie_A_2017]
Shots_2017 = pd.concat(All_leagues_2017)
Shots_2017
# Out:
#         id minute       result                   X                    Y  \
# 0   158133      1         Goal               0.885   0.5259999847412109
# 1   158136      7  MissedShots  0.8069999694824219                 0.72
# 2   158137     13    SavedShot  0.7859999847412109   0.6430000305175781
# 3   158138     21  BlockedShot  0.9059999847412109                0.605
# 4   158139     21  MissedShots  0.6759999847412109   0.5729999923706055
# ..     ...    ...          ...                 ...                  ...
# 11  216416     88   ShotOnPost  0.9209999847412109   0.6580000305175782
# 0   216403     29         Goal  0.9540000152587891   0.4779999923706055
# 1   216407     52  BlockedShot  0.8059999847412109   0.2560000038146973
# 2   216408     52  MissedShots  0.9690000152587891  0.37099998474121093
# 3   216410     57         Goal  0.9430000305175781  0.48900001525878906
#
#                       xG                   player h_a player_id situation  \
# ...

# %%
EPL_2018 = understat.season('EPL', 2018)
EPL_2018
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   232811      1  BlockedShot  0.8630000305175781    0.710999984741211
# 1   232812      2         Goal               0.885                  0.5
# 2   232818     39    SavedShot  0.7240000152587891                0.655
# 3   232819     40    SavedShot                0.88   0.6530000305175782
# 4   232821     55    SavedShot  0.7809999847412109                 0.33
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
La_liga_2018 = understat.season('La liga', 2018)
La_liga_2018
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   217848     11  MissedShots  0.7230000305175781    0.575999984741211
# 1   217849     15  MissedShots  0.9319999694824219   0.5579999923706055
# 2   217850     24    SavedShot  0.8159999847412109    0.769000015258789
# 3   217853     37  MissedShots  0.7240000152587891                0.605
# 4   217854     60  MissedShots                0.72  0.40299999237060546
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Ligue_1_2018 = understat.season('Ligue 1', 2018) 
Ligue_1_2018
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   217133      1  MissedShots   0.750999984741211    0.605999984741211
# 1   217134      8  BlockedShot  0.7119999694824218   0.5709999847412109
# 2   217135     17  MissedShots               0.895   0.5359999847412109
# 3   217136     18  MissedShots   0.919000015258789  0.40200000762939453
# 4   217137     21    SavedShot                 0.7                0.525
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Bundesliga_2018 = understat.season('Bundesliga', 2018)
Bundesliga_2018
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   219798      1  BlockedShot  0.9030000305175782   0.5670000076293945
# 1   219799      9  BlockedShot  0.8319999694824218   0.7069999694824218
# 2   219800     10  BlockedShot  0.9030000305175782                 0.55
# 3   219801     22         Goal  0.9669999694824218   0.5320000076293945
# 4   219803     30  BlockedShot  0.7719999694824219  0.43099998474121093
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Serie_A_2018 = understat.season('Serie A', 2018)
Serie_A_2018
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   218142     14  MissedShots  0.7290000152587891  0.40900001525878904
# 1   218145     21  MissedShots  0.7480000305175781    0.644000015258789
# 2   218150     37         Goal               0.895   0.5179999923706055
# 3   218153     55         Goal               0.885                  0.5
# 4   218158     66  MissedShots  0.7340000152587891   0.5420000076293945
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
All_leagues_2018 = [EPL_2018, La_liga_2018, Ligue_1_2018, Bundesliga_2018, Serie_A_2018]
Shots_2018 = pd.concat(All_leagues_2018)
Shots_2018
# Out:
#         id minute       result                   X                    Y  \
# 0   232811      1  BlockedShot  0.8630000305175781    0.710999984741211
# 1   232812      2         Goal               0.885                  0.5
# 2   232818     39    SavedShot  0.7240000152587891                0.655
# 3   232819     40    SavedShot                0.88   0.6530000305175782
# 4   232821     55    SavedShot  0.7809999847412109                 0.33
# ..     ...    ...          ...                 ...                  ...
# 11  304003     74  BlockedShot  0.8540000152587891    0.649000015258789
# 12  304004     75  MissedShots  0.7719999694824219   0.7230000305175781
# 13  304007     85    SavedShot   0.725999984741211  0.33599998474121096
# 14  304008     86  MissedShots   0.764000015258789   0.7230000305175781
# 15  304009     87    SavedShot   0.750999984741211  0.34799999237060547
#
#                       xG          player h_a player_id situation season  \
# ...

# %%
EPL_2019 = understat.season('EPL', 2019)
EPL_2019
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   309897     15  MissedShots  0.8830000305175781   0.7130000305175781
# 1   309898     18         Goal  0.9330000305175781  0.36700000762939455
# 2   309901     27         Goal  0.9219999694824219   0.5109999847412109
# 3   309902     30    SavedShot  0.8780000305175781                0.555
# 4   309904     41         Goal  0.8909999847412109                 0.53
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
La_liga_2019 = understat.season('La liga', 2019)
La_liga_2019
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   310745     30  MissedShots  0.9590000152587891  0.39799999237060546
# 1   310751     47    SavedShot  0.9030000305175782   0.6659999847412109
# 2   310753     50  BlockedShot  0.9390000152587891   0.5129999923706055
# 3   310754     57    SavedShot  0.9340000152587891  0.49599998474121093
# 4   310757     69  BlockedShot               0.745                 0.56
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Ligue_1_2019 = understat.season('Ligue 1', 2019) 
Ligue_1_2019
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   309873      9  BlockedShot                0.93   0.5479999923706055
# 1   309875     19  MissedShots  0.7930000305175782  0.36400001525878906
# 2   309876     21  MissedShots  0.7580000305175781  0.33599998474121096
# 3   309882     60    SavedShot  0.8909999847412109                0.425
# 4   309883     61  BlockedShot   0.845999984741211  0.39099998474121095
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Bundesliga_2019 = understat.season('Bundesliga', 2019)
Bundesliga_2019
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   310360      2    SavedShot  0.7830000305175782   0.5429999923706055
# 1   310361      6  MissedShots               0.815  0.43099998474121093
# 2   310364     16    SavedShot  0.9369999694824219   0.3940000152587891
# 3   310365     23         Goal  0.9359999847412109                0.505
# 4   310366     24    SavedShot   0.909000015258789  0.28700000762939454
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
Serie_A_2019 = understat.season('Serie A', 2019)
Serie_A_2019
# Out:
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:50: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   home_df = json_normalize(data['h'],sep='_')
# /Users/sarifarah/opt/anaconda3/lib/python3.9/site-packages/understatscraper/__init__.py:51: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   away_df = json_normalize(data['a'],sep='_')
#         id minute       result                   X                    Y  \
# 0   312658     12    SavedShot  0.8919999694824219                 0.63
# 1   312659     15    SavedShot   0.789000015258789  0.38299999237060545
# 2   312663     25  BlockedShot  0.7780000305175782                  0.6
# 3   312665     29  BlockedShot               0.765   0.6780000305175782
# 4   312669     48  BlockedShot               0.795                0.615
# ..     ...    ...          ...                 ...                  ...
# ...

# %%
All_leagues_2019 = [EPL_2019, La_liga_2019, Ligue_1_2019, Bundesliga_2019, Serie_A_2019]
Shots_2019 = pd.concat(All_leagues_2019)
Shots_2019
# Out:
#         id minute       result                   X                    Y  \
# 0   309897     15  MissedShots  0.8830000305175781   0.7130000305175781
# 1   309898     18         Goal  0.9330000305175781  0.36700000762939455
# 2   309901     27         Goal  0.9219999694824219   0.5109999847412109
# 3   309902     30    SavedShot  0.8780000305175781                0.555
# 4   309904     41         Goal  0.8909999847412109                 0.53
# ..     ...    ...          ...                 ...                  ...
# 8   374124     44  MissedShots  0.9219999694824219   0.3970000076293945
# 9   374128     56  BlockedShot  0.7759999847412109   0.4209999847412109
# 10  374129     57  MissedShots  0.9259999847412109                0.515
# 11  374132     66  MissedShots  0.9080000305175782   0.5370000076293945
# 12  374143     89  BlockedShot  0.8019999694824219   0.6309999847412109
#
#                       xG               player h_a player_id   situation  \
# ...

# %% [markdown]
# Now that I have all the data collected into seasons. I will concatenate all the seasons together and create a large dataset.

# %%
#concatenating all years data set into 1 table and renaming it 
All_leagues_all_years = [Shots_2015, Shots_2016, Shots_2017, Shots_2018, Shots_2019]
Shots_df_with_xg = pd.concat(All_leagues_all_years)
Shots_df_with_xg
# Out:
#         id minute       result                   X                    Y  \
# 0   200247     27  BlockedShot   0.794000015258789   0.4209999847412109
# 1   200248     27  BlockedShot                0.86   0.6270000076293946
# 2   200249     35  BlockedShot  0.8430000305175781  0.33299999237060546
# 3   200250     35  MissedShots  0.8480000305175781   0.5329999923706055
# 4   200251     40  BlockedShot  0.8119999694824219   0.7069999694824218
# ..     ...    ...          ...                 ...                  ...
# 8   374124     44  MissedShots  0.9219999694824219   0.3970000076293945
# 9   374128     56  BlockedShot  0.7759999847412109   0.4209999847412109
# 10  374129     57  MissedShots  0.9259999847412109                0.515
# 11  374132     66  MissedShots  0.9080000305175782   0.5370000076293945
# 12  374143     89  BlockedShot  0.8019999694824219   0.6309999847412109
#
#                       xG               player h_a player_id       situation  \
# ...

# %%
Shots_df_with_xg.to_csv('shots_df_with_xg.csv', index=False)

# %%
df1 = pd.read_csv('shots_df_with_xg.csv')
df1
# Out:
#         Unnamed: 0      id  minute       result      X      Y        xG  \
# 0                0  200247      27  BlockedShot  0.794  0.421  0.104347
# 1                1  200248      27  BlockedShot  0.860  0.627  0.064342
# 2                2  200249      35  BlockedShot  0.843  0.333  0.057157
# 3                3  200250      35  MissedShots  0.848  0.533  0.092141
# 4                4  200251      40  BlockedShot  0.812  0.707  0.035742
# ...            ...     ...     ...          ...    ...    ...       ...
# 227609           8  374124      44  MissedShots  0.922  0.397  0.013938
# 227610           9  374128      56  BlockedShot  0.776  0.421  0.024352
# 227611          10  374129      57  MissedShots  0.926  0.515  0.054011
# 227612          11  374132      66  MissedShots  0.908  0.537  0.036982
# 227613          12  374143      89  BlockedShot  0.802  0.631  0.022240
#
#                      player h_a  player_id  ... season   shotType match_id  \
# ...

# %% [markdown]
# I decide to remove the xG column as it is essentially what I want to model for. The xG column is not a part of the shot so i still preserve my raw data in order to do EDA.

# %%
#removing expected goals column 
# I am removing this because I want to generate this in my capstone project 
Shots_df_with_xg.drop(['xG'], axis=1)
Shots_df_final = Shots_df_with_xg.drop(['xG'], axis=1).copy()
Shots_df_final
# Out:
#         id minute       result                   X                    Y  \
# 0   200247     27  BlockedShot   0.794000015258789   0.4209999847412109
# 1   200248     27  BlockedShot                0.86   0.6270000076293946
# 2   200249     35  BlockedShot  0.8430000305175781  0.33299999237060546
# 3   200250     35  MissedShots  0.8480000305175781   0.5329999923706055
# 4   200251     40  BlockedShot  0.8119999694824219   0.7069999694824218
# ..     ...    ...          ...                 ...                  ...
# 8   374124     44  MissedShots  0.9219999694824219   0.3970000076293945
# 9   374128     56  BlockedShot  0.7759999847412109   0.4209999847412109
# 10  374129     57  MissedShots  0.9259999847412109                0.515
# 11  374132     66  MissedShots  0.9080000305175782   0.5370000076293945
# 12  374143     89  BlockedShot  0.8019999694824219   0.6309999847412109
#
#                  player h_a player_id       situation season   shotType  \
# ...

# %%
#saving the dataset as a CSV 
Shots_df_final.to_csv('shots_df_EDA.csv', index=False)

# %%
#making sure it saved and re-uploaded 
df2 = pd.read_csv('shots_df_EDA.csv')
df2
# Out:
#             id  minute       result      X      Y               player h_a  \
# 0       200247      27  BlockedShot  0.794  0.421            Juan Mata   h
# 1       200248      27  BlockedShot  0.860  0.627        Memphis Depay   h
# 2       200249      35  BlockedShot  0.843  0.333            Juan Mata   h
# 3       200250      35  MissedShots  0.848  0.533            Juan Mata   h
# 4       200251      40  BlockedShot  0.812  0.707        Memphis Depay   h
# ...        ...     ...          ...    ...    ...                  ...  ..
# 227609  374124      44  MissedShots  0.922  0.397  Ernesto Torregrossa   a
# 227610  374128      56  BlockedShot  0.776  0.421        Sandro Tonali   a
# 227611  374129      57  MissedShots  0.926  0.515  Ernesto Torregrossa   a
# 227612  374132      66  MissedShots  0.908  0.537  Ernesto Torregrossa   a
# 227613  374143      89  BlockedShot  0.802  0.631  Ernesto Torregrossa   a
#
#         player_id       situation  season   shotType  match_id  \
# ...

# %% [markdown]
# Now we will move on to EDA in the next notebook.
